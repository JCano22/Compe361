# %% [markdown]
# ## Notes
# -Review 'and' 'or', etc....

# %%
print("Test")
p = 35
q = 10
r = p + q
print(r)

r = p - q
print(r)

r = p * q
print(r)

r = p / q
print(r)
# Out:
# Test
# 45
# 25
# 350
# 3.5
